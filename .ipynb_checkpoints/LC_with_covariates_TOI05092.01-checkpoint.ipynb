# %% [markdown]
# # 教科書用
#
# False PositiveのLCと、LCとcovariatesの関係を明らかにする！！ (IRSFのデータがどっかに行ってしまったんだ・・・)

# %%
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as pl
import numpy as np
from glob import glob

# %%
bands = ['g','r','i','z']
colors = ['b','g','orange','r']

# %%
dfs = []
for b in bands:
    file = glob(f'data/TOI05092.01_240215_muscat2_{b}*.csv')[0]
    df = pd.read_csv(file)
    dfs.append(df)

# %%
f, axs = pl.subplots(
    5, 4, 
    sharex=True, sharey='row',
    gridspec_kw={"height_ratios": [2.5, 1, 1, 1, 1]},
    figsize=(12, 6)
)
pl.subplots_adjust(wspace=0.1, hspace=0)
