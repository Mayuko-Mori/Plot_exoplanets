# %% [markdown]
# # 教科書用
#
# False PositiveのLCと、LCとcovariatesの関係を明らかにする！！ (IRSFのデータがどっかに行ってしまったんだ・・・)

# %%
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as pl
import numpy as np
from glob import glob

# %%
bands = ['g','r','i','z']
colors = ['b','g','orange','r']

# %%
glob(f'data/TOI-519b_*{b}_*.csv')
# Out:
# ['data/TOI-519b_220123_muscat3_g_c8_r8.csv']

# %%
dfs = []
for b in bands:
    file = glob(f'data/TOI-519b_*{b}_*.csv')[0]
    df = pd.read_csv(file)
    dfs.append(df)

# %%
import sys
sys.path.append("/ut3/mori/work/git_repo/my_tools/")
import binning

# %%
df
# Out:
#           BJD_TDB     Flux      Err  Airmass  DX(pix)  DY(pix)  FWHM(pix)  \
# 0    2.459604e+06  1.00268  0.00201   1.3151    -0.85    -0.08       4.96
# 1    2.459604e+06  1.00357  0.00204   1.3148    -0.34    -0.07       5.02
# 2    2.459604e+06  1.00000  0.00205   1.3144    -0.03     0.09       6.25
# 3    2.459604e+06  1.00086  0.00202   1.3141    -0.92    -0.61       5.67
# 4    2.459604e+06  1.00436  0.00208   1.3139    -0.33    -0.59       6.54
# ..            ...      ...      ...      ...      ...      ...        ...
# 169  2.459604e+06  1.00647  0.00261   2.0500     2.49    -2.46       9.02
# 170  2.459604e+06  1.00571  0.00250   2.0751    -1.24     0.61       8.92
# 171  2.459604e+06  1.00574  0.00253   2.0879     2.85    -0.81      10.28
# 172  2.459604e+06  1.00287  0.00254   2.1010     3.19    -1.94       9.13
# 173  2.459604e+06  1.00400  0.00267   2.1143    -1.66     0.73      11.77
#
#      Peak(ADU)
# 0        42676
# 1        40431
# 2        30260
# 3        37172
# 4        25336
# ..         ...
# 169      14101
# 170      15304
# 171      12615
# 172      13869
# 173       9390
#
# [174 rows x 8 columns]

# %%
dfs_bin= []
binsize=5/60/24 #day

f, axs =pl.subplots(len(bands),1,figsize=(12, 8),sharex=True)
for n, band in enumerate(bands):
    df = dfs[n]
    time = df['BJD_TDB']
    flux= df['Flux']
    err = df['Err']
    
    axs[n].errorbar(time, flux, err, fmt='.', color='gray', alpha=0.1)
    tbin, fbin, febin = binning.binning_equal_interval(np.array(time), np.array(flux), np.array(err), binsize=binsize, t0=np.array(time)[0])
    axs[n].errorbar(tbin, fbin, febin, fmt='.', color=colors[n])
    
    print(len(tbin))
    
    df_bin = pd.DataFrame({'BJD_TDB':tbin,'Flux':fbin,'Err':febin})
    dfs_bin.append(df_bin)
# Out:
# 41
# 42
# 42
# 41

# %%
dfs[0].columns
# Out:
# Index(['BJD_TDB', 'Flux', 'Err', 'Airmass', 'DX(pix)', 'DY(pix)', 'FWHM(pix)',
#        'Peak(ADU)'],
#       dtype='object')

# %%
offset = 2459604

# %%
f, axs = pl.subplots(
    4, 4, 
    sharex=True, sharey='row',
    gridspec_kw={"height_ratios": [2.5, 1, 1, 1]},
    figsize=(14, 6)
)
pl.subplots_adjust(wspace=0.05, hspace=0)


for n_b, b in enumerate(bands):
    df = dfs[n_b]
    time = df['BJD_TDB']-offset
    axs[0][n_b].plot(time, df['Flux'], '.', color='gray', alpha=0.4, ms=2)
    
    axs[1][n_b].plot(time, df['DX(pix)'], '-', color='magenta', lw=1)
    axs[1][n_b].plot(time, df['DY(pix)'], '-', color='orange', lw=1)
    
    axs[2][n_b].plot(time, df['FWHM(pix)'], '-', color='steelblue', lw=1)
    axs[3][n_b].plot(time, df['Airmass'], '-', color='k', lw=1)
    
    df = dfs_bin[n_b]
    time = df['BJD_TDB']-offset
    axs[0][n_b].errorbar(time, df['Flux'], df['Err'], fmt='.', color=colors[n_b], capsize=2)
    axs[0][n_b].set_xlim(-0.03, 0.06)
    #axs[0][n_b].set_ylim(0.99, 1.01)
    
    for i in range(4):
        axs[i][n_b].tick_params(axis='both', which='major', labelsize=12)
        
    axs[0][n_b].text(0.05, 0.88, b, color=colors[n_b], fontsize=16)

    
#axs[1][3].text(0.6, -8, 'dx', color='magenta', fontsize=16)
#axs[1][3].text(0.612, -8, 'dy', color='orange', fontsize=16)


f.supxlabel(f'BJD - {offset}', fontsize=16, y=0.02)
axs[0][0].set_ylabel('Normalized Flux', fontsize=16, labelpad=20)
axs[1][0].set_ylabel('dxdy (pix)', fontsize=16, labelpad=10)
axs[2][0].set_ylabel('FWHM (pix)', fontsize=16, labelpad=40)
axs[3][0].set_ylabel('Airmass', fontsize=16, labelpad=10)

f.suptitle("2022 Jan 23, TOI-519b (MuSCAT3)", fontsize=18, y=0.94)

#for i in range(4):
#    for j in range(4):
#        axs[i][j].set_xticks([0.53, 0.56, 0.59, 0.62])  
        
f.savefig('TOI-519b_LC.pdf', bbox_inches='tight')

# %%
df = dfs[2]

# %%
import seaborn as sns

corr = df.corr().abs()
pl.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <AxesSubplot: >
