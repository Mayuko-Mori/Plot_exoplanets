# %%
import os
os.environ["OMP_NUM_THREADS"]="1"
os.nice(19)
# Out:
# 19

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pl
from astropy.io import fits
import pandas as pd
import sys
import scipy
from scipy import stats
from astropy.visualization import ZScaleInterval
from uncertainties import ufloat 
from glob import glob
import csv
from scipy import constants
from astropy import units as u
from astropy import constants as ascon
import time as tm
import datetime
import re

from PyAstronomy.pyTiming import pyPeriod
from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
from glob import glob

# %%
import lightkurve as lk

# %%
target ='K2-25'
#search_result = lk.search_lightcurve(target, author='QLP')
search_result = lk.search_lightcurve(target)
search_result
# Out:
# SearchResult containing 17 data products.
#
#  #     mission     year   author  exptime  target_name  distance
#                                      s                   arcsec
# --- -------------- ---- --------- ------- ------------- --------
#   0 K2 Campaign 04 2015        K2    1800 ktwo210490365      0.0
#   1 K2 Campaign 04 2015   EVEREST    1800 ktwo210490365      0.0
#   2 K2 Campaign 04 2015      K2SC    1800 ktwo210490365      0.0
#   3 K2 Campaign 04 2015     K2SFF    1800 ktwo210490365      0.0
#   4 K2 Campaign 04 2015  K2VARCAT    1800 ktwo210490365      0.0
#   5 TESS Sector 44 2021      SPOC     120     434226736      0.0
# ...            ...  ...       ...     ...           ...      ...
#  11 TESS Sector 70 2023 TESS-SPOC     200     434226736      0.0
#  12 TESS Sector 70 2023       QLP     200     434226736      0.0
#  13 TESS Sector 71 2023      SPOC      20     434226736      0.0
#  14 TESS Sector 71 2023      SPOC     120     434226736      0.0
#  15 TESS Sector 71 2023 TESS-SPOC     200     434226736      0.0
#  16 TESS Sector 71 2023       QLP     200     434226736      0.0
# Length = 17 rows

# %%
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive

# %%
target_table = NasaExoplanetArchive.query_object(target, table='ps')
target_table
# Out:
# WARNING: Unrecognized unit: 'hour' for column pl_trandur. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# WARNING: Unrecognized unit: 'hour' for column pl_trandurerr1. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# WARNING: Unrecognized unit: 'hour' for column pl_trandurerr2. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# <QTable masked=True length=6>
# pl_name pl_letter hostname ... sy_kmagerr1 sy_kmagerr2       sky_coord
#                            ...     mag         mag            deg,deg
#   str7     str1     str5   ...   float64     float64          SkyCoord
# ------- --------- -------- ... ----------- ----------- ---------------------
# K2-25 b         b    K2-25 ...       0.019      -0.019 63.2739346,15.2477027
# K2-25 b         b    K2-25 ...       0.019      -0.019 63.2739346,15.2477027
# K2-25 b         b    K2-25 ...       0.019      -0.019 63.2739346,15.2477027
# K2-25 b         b    K2-25 ...       0.019      -0.019 63.2739346,15.2477027
# K2-25 b         b    K2-25 ...       0.019      -0.019 63.2739346,15.2477027
# K2-25 b         b    K2-25 ...       0.019      -0.019 63.2739346,15.2477027

# %%
ttable = target_table[0]

# %%
tic_id = ttable['tic_id']

# %%
offset= 2457000

T0 = float(ttable['pl_tranmid'].value)-offset #day
P =  float(ttable['pl_orbper'].value) #day

print(T0, P)
# Out:
# 62.5793499997817 3.484552

# %%
n=5
lc = search_result[5].download()
#lc = lc.remove_nans().remove_outliers()

lc.time.value
# Out:
# array([2500.19232592, 2500.19371491, 2500.1951039 , ..., 2524.44218822,
#        2524.44357715, 2524.44496608])

# %%
t_start= int(np.ceil((lc.time.value[0]-T0)/P))
t_end = int(np.ceil((lc.time.value[-1]-T0)/P))
ts = np.arange(t_start, t_end)
ts
# Out:
# array([700, 701, 702, 703, 704, 705, 706])

# %%
n=5
lc = search_result[5].download()
#lc = lc.remove_nans().remove_outliers()

f = pl.figure(figsize=(8, 4))

pl.plot(lc.time.value, lc.pdcsap_flux.value/np.median(lc.pdcsap_flux.value), '.', ms=0.8, color='k')

pl.vlines(ts*P+T0, 0.95, 1.20, color='tomato', zorder=-1)
 
pl.title(f'{search_result[n].mission[0]} data of {target} ({tic_id})')

pl.xlabel(f'BJD (-{offset})', fontsize=12)
pl.ylabel('Normalized flux', fontsize=12)

pl.ylim(0.95, 1.20)

f.savefig('LC_K2-25.png')
#pl.tight_layout()
