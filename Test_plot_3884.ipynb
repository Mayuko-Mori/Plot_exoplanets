# %%
import pandas as pd
import matplotlib.pyplot as pl
import matplotlib.pyplot as plt
import numpy as np
from glob import glob

# %%
data_mon = pd.read_csv('/Users/mayuko2/Downloads/TOI-3884_LCO1m_astropy_r_rad8_cc_gaia_conditioned.csv')
pl.errorbar(data_mon['mjd'], data_mon['flux'], data_mon['err'], fmt='.')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
data_transit = pd.read_csv('/Users/mayuko2/Downloads/data_2/TOI-3884_240219_muscat3_r_c34_r12.csv')
pl.errorbar(data_transit['BJD_TDB'], data_transit['Flux'], data_transit['Err'], fmt='.')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
data_transit = pd.read_csv('/Users/mayuko2/Downloads/data_2/TOI-3884_threedate_combine_r.csv')[41:80]
pl.errorbar(data_transit['BJD_TDB'], data_transit['Flux'], data_transit['Err'], fmt='.')
# Out:
# <ErrorbarContainer object of 3 artists>
