# %%
import os
os.environ["OMP_NUM_THREADS"]="1"
os.nice(19)
# Out:
# 19

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pl
from astropy.io import fits
import pandas as pd
import sys
import scipy
from scipy import stats
from astropy.visualization import ZScaleInterval
from uncertainties import ufloat 
from glob import glob
import csv
from scipy import constants
from astropy import units as u
from astropy import constants as ascon
import time as tm
import datetime
import re

from PyAstronomy.pyTiming import pyPeriod
from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
from glob import glob

# %%
import lightkurve as lk

# %%
target ='K2-25'
#search_result = lk.search_lightcurve(target, author='QLP')
search_result = lk.search_lightcurve(target)
search_result
# Out:
# ---------------------------------------------------------------------------
# RemoteServiceError                        Traceback (most recent call last)
# Cell In[7], line 3
#       1 target ='K2-25'
#       2 #search_result = lk.search_lightcurve(target, author='QLP')
# ----> 3 search_result = lk.search_lightcurve(target)
#       4 search_result
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/memoization/caching/plain_cache.py:42, in get_caching_wrapper.<locals>.wrapper(*args, **kwargs)
#      40 with lock:
#      41     misses += 1
# ---> 42 result = user_function(*args, **kwargs)
#      43 cache[key] = values_toolkit.make_cache_value(result, ttl)
#      44 key_argument_map[key] = (args, kwargs)
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/lightkurve/search.py:843, in search_lightcurve(target, radius, exptime, cadence, mission, author, quarter, month, campaign, sector, limit)
#     743 """Search the `MAST data archive <https://archive.stsci.edu>`_ for light curves.
#     744
#     745 This function fetches a data table that lists the Light Curve Files
#    (...)
#     840     >>> search_lightcurve('Kepler-10', radius=100, quarter=4, exptime=1800).download_all()  # doctest: +SKIP
#     841 """
#     842 try:
# --> 843     return _search_products(
#     844         target,
#     845         radius=radius,
#     846         filetype="Lightcurve",
#     847         exptime=exptime or cadence,
#     848         mission=mission,
#     849         provenance_name=author,
#     850         quarter=quarter,
#     851         month=month,
#     852         campaign=campaign,
#     853         sector=sector,
#     854         limit=limit,
#     855     )
#     856 except SearchError as exc:
#     857     log.error(exc)
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/lightkurve/search.py:991, in _search_products(target, radius, filetype, mission, provenance_name, exptime, quarter, month, campaign, sector, limit, **extra_query_criteria)
#     989 if filetype.lower() == "ffi" and radius is None:
#     990     radius = 0.0001 * u.arcsec
# --> 991 observations = _query_mast(
#     992     target,
#     993     radius=radius,
#     994     project=mission,
#     995     provenance_name=provenance_name,
#     996     exptime=exptime,
#     997     sequence_number=campaign or sector,
#     998     **extra_query_criteria,
#     999 )
#    1000 log.debug(
#    1001     "MAST found {} observations. "
#    1002     "Now querying MAST for the corresponding data products."
#    1003     "".format(len(observations))
#    1004 )
#    1005 if len(observations) == 0:
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/lightkurve/search.py:1218, in _query_mast(target, radius, project, provenance_name, exptime, sequence_number, **extra_query_criteria)
#    1216     warnings.filterwarnings("ignore", category=NoResultsWarning)
#    1217     warnings.filterwarnings("ignore", message="t_exptime is continuous")
# -> 1218     obs = Observations.query_criteria(objectname=target, **query_criteria)
#    1219 obs.sort("distance")
#    1220 # We use `exptime` as an alias for `t_exptime`
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/astroquery/utils/class_or_instance.py:25, in class_or_instance.__get__.<locals>.f(*args, **kwds)
#      23 def f(*args, **kwds):
#      24     if obj is not None:
# ---> 25         return self.fn(obj, *args, **kwds)
#      26     else:
#      27         return self.fn(cls, *args, **kwds)
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/astroquery/utils/process_asyncs.py:29, in async_to_sync.<locals>.create_method.<locals>.newmethod(self, *args, **kwargs)
#      27 if kwargs.get('get_query_payload') or kwargs.get('field_help'):
#      28     return response
# ---> 29 result = self._parse_result(response, verbose=verbose)
#      30 self.table = result
#      31 return result
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/astroquery/mast/observations.py:77, in ObservationsClass._parse_result(self, responses, verbose)
#      59 def _parse_result(self, responses, *, verbose=False):  # Used by the async_to_sync decorator functionality
#      60     """
#      61     Parse the results of a list of `~requests.Response` objects and returns an `~astropy.table.Table` of results.
#      62
#    (...)
#      74     response : `~astropy.table.Table`
#      75     """
# ---> 77     return self._portal_api_connection._parse_result(responses, verbose)
#
# File /ut3/mori/ls/envs/py39/lib/python3.9/site-packages/astroquery/mast/discovery_portal.py:291, in PortalAPI._parse_result(self, responses, verbose)
#     289 # check for error message
#     290 if result['status'] == "ERROR":
# --> 291     raise RemoteServiceError(result.get('msg', "There was an error with your request."))
#     293 result_table = _json_to_table(result, col_config)
#     294 result_list.append(result_table)
#
# RemoteServiceError: Logon failed for login 'STSCI\mastiisdist' due to trigger execution.
# Changed database context to 'CAOMv240'.
# Changed language setting to us_english.

# %%
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive

# %%
target_table = NasaExoplanetArchive.query_object(target, table='ps')
target_table

# %%
ttable = target_table[0]

# %%
tic_id = ttable['tic_id']

# %%
offset= 2457000

T0 = float(ttable['pl_tranmid'].value)-offset #day
P =  float(ttable['pl_orbper'].value) #day

print(T0, P)

# %%
n=5
lc = search_result[5].download()
#lc = lc.remove_nans().remove_outliers()

lc.time.value

# %%
t_start= int(np.ceil((lc.time.value[0]-T0)/P))
t_end = int(np.ceil((lc.time.value[-1]-T0)/P))
ts = np.arange(t_start, t_end)
ts

# %%
n=5
lc = search_result[5].download()
#lc = lc.remove_nans().remove_outliers()

f = pl.figure(figsize=(12, 5))

pl.plot(lc.time.value, lc.pdcsap_flux.value/np.median(lc.pdcsap_flux.value), '.', ms=0.8, color='k')

pl.vlines(ts*P+T0, 0.95, 1.20, color='tomato', zorder=-1)
 
pl.title(f'{search_result[n].mission[0]} data of {target} ({tic_id})', fontsize=15)

pl.xlabel(f'BJD (-{offset})', fontsize=15)
pl.ylabel('Normalized flux', fontsize=15)
pl.tick_params(axis='both', which='major', labelsize=14)


pl.ylim(0.95, 1.20)

f.savefig('LC_K2-25.pdf', bbox_inches='tight')
#pl.tight_layout()
